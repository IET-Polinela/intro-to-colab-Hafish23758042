# %%
from google.colab import auth
auth.authenticate_user()
# !git config --global user.email "nagaapi1145@gmail.com"
# !git config --global user.name "Hafish23758042"
# !git clone https://[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]@github.com/[Hafish23758042]/[https://github.com/IET-Polinela/intro-to-colab-Hafish23758042].git
# %cd [https://github.com/IET-Polinela/intro-to-colab-Hafish23758042]
# Out:
# Cloning into 'intro-to-colab-Hafish23758042]'...
# fatal: repository 'https://github.com/[Hafish23758042]/[https://github.com/IET-Polinela/intro-to-colab-Hafish23758042].git/' not found
# [Errno 2] No such file or directory: '[https://github.com/IET-Polinela/intro-to-colab-Hafish23758042]'
# /content

# %%
from google.colab import auth
auth.authenticate_user()

# Konfigurasi identitas GitHub
# !git config --global user.email "nagaapi1145@gmail.com"
# !git config --global user.name "Hafish23758042"

# Gunakan akses token yang disimpan sebagai secret (lebih aman daripada hardcoding)
access_token = "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"
repo_owner = "IET-Polinela"
repo_name = "intro-to-colab-Hafish23758042"

# Cloning repository
# !git clone https://{access_token}@github.com/{repo_owner}/{repo_name}.git

# Masuk ke direktori repository
# %cd {repo_name}
# Out:
# Cloning into 'intro-to-colab-Hafish23758042'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 560.63 KiB | 12.19 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/intro-to-colab-Hafish23758042

# %%
# !git add LAB1_23758042.ipynb
# !git commit -m "ipload ipynb"
# !git commit push origin main
# Out:
# fatal: pathspec 'LAB1_23758042.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# error: pathspec 'push' did not match any file(s) known to git
# error: pathspec 'origin' did not match any file(s) known to git
# error: pathspec 'main' did not match any file(s) known to git

# %%
# %%writefile mnst_cnn.py
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load dataset MNIST
mnist = keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data
X_train, X_test = X_train / 255.0, X_test / 255.0

# Buat model CNN
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Training model & simpan history
history = model.fit(X_train.reshape(-1, 28, 28, 1), y_train, epochs=5,
                    validation_data=(X_test.reshape(-1, 28, 28, 1), y_test))

# Evaluasi model
test_loss, test_acc = model.evaluate(X_test.reshape(-1, 28, 28, 1), y_test)
print(f"Test accuracy: {test_acc:.2f}")

# Simpan hasil evaluasi ke file teks
with open("evaluation.txt", "w") as f:
    f.write(f"Test Loss: {test_loss:.4f}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
print("Evaluation results saved to evaluation.txt.")

# Visualisasi loss & accuracy
history_dict = history.history
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot Loss
ax[0].plot(history_dict['loss'], label='Train Loss', marker='o')
ax[0].plot(history_dict['val_loss'], label='Validation Loss', marker='o')
ax[0].set_title("Model Loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()

# Plot Accuracy
ax[1].plot(history_dict['accuracy'], label='Train Accuracy', marker='o')
ax[1].plot(history_dict['val_accuracy'], label='Validation Accuracy', marker='o')
ax[1].set_title("Model Accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

# Simpan grafik ke dalam file
plt.savefig("training_performance.png")
plt.show()

print("Training performance plot saved to training_performance.png.")
# Out:
# Writing mnst_cnn.py

# %%
# !python mnst_cnn.py
# Out:
# 2025-03-03 04:22:07.626239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740975727.645523    1824 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740975727.651158    1824 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:22:07.670430: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-03 04:22:14.421091: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1740975734.422794    1824 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740975737.948895    1870 service.cc:148] XLA service 0x78324c005980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740975737.949198    1870 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-03-03 04:22:18.003191: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1740975738.140142    1870 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-03 04:22:19.074992: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# I0000 00:00:1740975740.284571    1870 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.30042025-03-03 04:22:24.725020: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-03 04:22:25.637951: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9078 - loss: 0.3003 - val_accuracy: 0.9817 - val_loss: 0.0575
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9832 - loss: 0.0558 - val_accuracy: 0.9857 - val_loss: 0.0429
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9901 - loss: 0.0315 - val_accuracy: 0.9865 - val_loss: 0.0433
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9940 - loss: 0.0191 - val_accuracy: 0.9857 - val_loss: 0.0450
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9959 - loss: 0.0133 - val_accuracy: 0.9873 - val_loss: 0.0427
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9842 - loss: 0.0529
# Test accuracy: 0.99
# Evaluation results saved to evaluation.txt.
# Figure(1200x500)
# Training performance plot saved to training_performance.png.

# %%
# !git add .

# %%
# !python mnst_cnn.py
# Out:
# 2025-03-03 04:26:52.702055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740976012.720764    3179 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740976012.726669    3179 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:26:52.746411: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-03 04:26:57.429858: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1740976017.430030    3179 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740976019.655001    3216 service.cc:148] XLA service 0x7950c80092c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740976019.655051    3216 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-03-03 04:26:59.687089: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1740976019.785200    3216 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-03 04:27:00.053355: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# I0000 00:00:1740976020.910652    3216 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.27542025-03-03 04:27:05.937492: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-03 04:27:06.837627: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,32,26,26]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1,28,28]{3,2,1,0}, f32[32,1,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9193 - loss: 0.2748 - val_accuracy: 0.9822 - val_loss: 0.0559
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9853 - loss: 0.0492 - val_accuracy: 0.9859 - val_loss: 0.0401
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9913 - loss: 0.0291 - val_accuracy: 0.9843 - val_loss: 0.0451
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9939 - loss: 0.0198 - val_accuracy: 0.9867 - val_loss: 0.0417
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9964 - loss: 0.0127 - val_accuracy: 0.9867 - val_loss: 0.0453
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.0571
# Test accuracy: 0.99
# Evaluation results saved to evaluation.txt.
# Figure(1200x500)
# Training performance plot saved to training_performance.png.

# %%
# !git add mnst_cnn.py evaluation.txt training_performance.png training_performance\(GPU\).png
# !git commit -m "Upload mnst_cnn, hasil GPU dan CPU, dan evaluation"
# !git push origin main
# Out:
# [main 7605bec] Upload mnst_cnn, hasil GPU dan CPU, dan evaluation
#  4 files changed, 65 insertions(+)
#  create mode 100644 evaluation.txt
#  create mode 100644 mnst_cnn.py
#  create mode 100644 training_performance(GPU).png
#  create mode 100644 training_performance.png
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 95.71 KiB | 11.96 MiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/IET-Polinela/intro-to-colab-Hafish23758042.git
#    1c49a0d..7605bec  main -> main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python iris_knn.py
# Out:
# Accuracy: 1.00
# Figure(600x400)

# %%
# !git add .
# !git commit -m "Upload iris_knn.py"
# !git push origin main
# Out:
# [main 1c49a0d] Upload iris_knn.py
#  2 files changed, 46 insertions(+)
#  create mode 100644 iris_knn.py
#  create mode 100644 knn_confusion_matrix.png
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 19.54 KiB | 19.54 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/IET-Polinela/intro-to-colab-Hafish23758042.git
#    19242e6..1c49a0d  main -> main

# %%
# %%writefile iris_knn.py
# Out:
# Overwriting iris_knn.py

# %%
# !python mnist_cnn.py
# Out:
# 2025-03-03 03:44:11.964981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740973452.030926   14159 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740973452.057569   14159 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 03:44:12.141258: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-03 03:44:17.457916: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9137 - loss: 0.2968 - val_accuracy: 0.9795 - val_loss: 0.0603
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 13ms/step - accuracy: 0.9842 - loss: 0.0515 - val_accuracy: 0.9848 - val_loss: 0.0473
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9915 - loss: 0.0278 - val_accuracy: 0.9852 - val_loss: 0.0449
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - accuracy: 0.9948 - loss: 0.0184 - val_accuracy: 0.9870 - val_loss: 0.0405
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 12ms/step - accuracy: 0.9963 - loss: 0.0119 - val_accuracy: 0.9866 - val_loss: 0.0468
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9834 - loss: 0.0584
# Test accuracy: 0.99
# Evaluation results saved to evaluation.txt.
# Figure(1200x500)
# Training performance plot saved to training_performance.png.

# %%
# !python mnist_cnn.py
# Out:
# python3: can't open file '/content/mnist_cnn.py': [Errno 2] No such file or directory

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load dataset MNIST
mnist = keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data
X_train, X_test = X_train / 255.0, X_test / 255.0

# Buat model CNN
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Training model & simpan history
history = model.fit(X_train.reshape(-1, 28, 28, 1), y_train, epochs=5,
                    validation_data=(X_test.reshape(-1, 28, 28, 1), y_test))

# Evaluasi model
test_loss, test_acc = model.evaluate(X_test.reshape(-1, 28, 28, 1), y_test)
print(f"Test accuracy: {test_acc:.2f}")

# Simpan hasil evaluasi ke file teks
with open("evaluation.txt", "w") as f:
    f.write(f"Test Loss: {test_loss:.4f}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
print("Evaluation results saved to evaluation.txt.")

# Visualisasi loss & accuracy
history_dict = history.history
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot Loss
ax[0].plot(history_dict['loss'], label='Train Loss', marker='o')
ax[0].plot(history_dict['val_loss'], label='Validation Loss', marker='o')
ax[0].set_title("Model Loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()

# Plot Accuracy
ax[1].plot(history_dict['accuracy'], label='Train Accuracy', marker='o')
ax[1].plot(history_dict['val_accuracy'], label='Validation Accuracy', marker='o')
ax[1].set_title("Model Accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

# Simpan grafik ke dalam file
plt.savefig("training_performance.png")
plt.show()

print("Training performance plot saved to training_performance.png.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9145 - loss: 0.2882 - val_accuracy: 0.9785 - val_loss: 0.0651
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9847 - loss: 0.0521 - val_accuracy: 0.9843 - val_loss: 0.0454
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9902 - loss: 0.0306 - val_accuracy: 0.9872 - val_loss: 0.0379
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9946 - loss: 0.0172 - val_accuracy: 0.9848 - val_loss: 0.0520
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9958 - loss: 0.0132 - val_accuracy: 0.9862 - val_loss: 0.0421
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.0503
# Test accuracy: 0.99
# Evaluation results saved to evaluation.txt.
# Training performance plot saved to training_performance.png.

# %%
# !python mnst_cnn.py
# Out:
# 2025-03-03 04:13:38.644389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740975218.673088     634 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740975218.680370     634 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:13:38.705010: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-03 04:13:43.631603: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.9146 - loss: 0.2895 - val_accuracy: 0.9794 - val_loss: 0.0610
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.9847 - loss: 0.0500 - val_accuracy: 0.9842 - val_loss: 0.0454
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.9911 - loss: 0.0292 - val_accuracy: 0.9851 - val_loss: 0.0449
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.9944 - loss: 0.0183 - val_accuracy: 0.9858 - val_loss: 0.0485
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.9968 - loss: 0.0105 - val_accuracy: 0.9845 - val_loss: 0.0433
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9807 - loss: 0.0526
# Test accuracy: 0.98
# Evaluation results saved to evaluation.txt.
# Figure(1200x500)
# Training performance plot saved to training_performance.png.

# %%
# %%writefile mnst_cnn.py
# Out:
# Overwriting mnst_cnn.py

# %%
# !python mnst_cnn.py
# Out:
# 2025-03-03 04:01:02.413170: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740974462.523140    2566 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740974462.539553    2566 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:01:02.600135: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-03 04:01:09.022259: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 0.9144 - loss: 0.2940 - val_accuracy: 0.9819 - val_loss: 0.0573
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.9844 - loss: 0.0529 - val_accuracy: 0.9824 - val_loss: 0.0520
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - accuracy: 0.9899 - loss: 0.0310 - val_accuracy: 0.9849 - val_loss: 0.0471
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.9943 - loss: 0.0185 - val_accuracy: 0.9863 - val_loss: 0.0421
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.9955 - loss: 0.0153 - val_accuracy: 0.9852 - val_loss: 0.0518
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9814 - loss: 0.0642
# Test accuracy: 0.99
# Evaluation results saved to evaluation.txt.
# Figure(1200x500)
# Training performance plot saved to training_performance.png.
